# %% [markdown]
# # Importing the Necessary Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Importing the Data Set

# %%
data = pd.read_csv("cancer.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# understanding the data type 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Finding missing values

# %% [markdown]
#  # Data Preprocessing

# %%
data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# No missing Values

# %%
# OUTLIER REMOVAL

# %%
df = data.drop("diagnosis",1)
# Out:
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/623550732.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = data.drop("diagnosis",1)

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()
# Out:
# C:\Users\Khannchan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Khannchan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Khannchan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# Removal of outliers

# %%
for values in df.columns:
    
    q1 = np.percentile( df[values], 25, interpolation = 'midpoint')
    q3 = np.percentile( df[values], 75, interpolation = 'midpoint')
    
    iqr= q3-q1
    
    df[values].drop(df[(df[values]>=(q3+1.5*iqr))|(df[values]<=(q1-1.5*iqr))].index,inplace=True)
# Out:
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/158593432.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1 = np.percentile( df[values], 25, interpolation = 'midpoint')
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/158593432.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3 = np.percentile( df[values], 75, interpolation = 'midpoint')

# %%
for i in df.columns:
    sns.kdeplot(df[i])
    plt.show()

# %%
# Label Encoding for the Dependent Variable

# %%
y_dep = data["diagnosis"]

# %%
y_dep = pd.get_dummies(y_dep)

# %%
y_dep = y_dep.drop("B",1)
# Out:
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/3362853040.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   y_dep = y_dep.drop("B",1)

# %%
y_dep
# Out:
#      M
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 564  1
# 565  1
# 566  1
# 567  1
# 568  0
#
# [569 rows x 1 columns]

# %%
# if the value for malignant is 0 then we go for Belignent which means they dont have cancer

# %%
# Scaling : Since they follow a normal distribution we go for Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
data = data.drop("diagnosis",1)
# Out:
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/295452477.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop("diagnosis",1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/295452477.py in <module>
# ----> 1 data = data.drop("diagnosis",1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# ...

# %%
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data = data.drop("id",1)
# Out:
# C:\Users\KHANNC~1\AppData\Local\Temp/ipykernel_12584/4168736285.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop("id",1)

# %%
data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
new = ss.fit_transform(data)

# %%
new
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
# Train test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_traian,y_test = train_test_split(new,y_dep,test_size=0.3)

# %%
from sklearn import svm

# %%
sup = svm.SVC(probability=True)

# %%
sup.fit(x_train,y_traian)
# Out:
# SVC(probability=True)

# %%
# predicting the SVc

# %%
train_pred = sup.predict(x_train)

# %%
test_pred = sup.predict(x_test)

# %% [markdown]
# # Accuracy Score

# %%
from sklearn.metrics import accuracy_score

# %%
acc_train = accuracy_score(y_traian,train_pred)

# %%
acc_train
# Out:
# 0.9874371859296482

# %%
acc_test = accuracy_score(y_test,test_pred)

# %%
acc_test
# Out:
# 0.9766081871345029

# %% [markdown]
# # Precision

# %%
from sklearn.metrics import precision_score

# %%
pre_train = precision_score(y_traian,train_pred)
pre_train
# Out:
# 1.0

# %%
pre_test = precision_score(y_test,test_pred)
pre_test
# Out:
# 0.975609756097561

# %%
# Model seems to be overfitting a bit

# %% [markdown]
# # Senstitivity and Specificity

# %%
from sklearn.metrics import confusion_matrix

# %%
# for training data

# %%
print(confusion_matrix(y_traian,train_pred))
cm = confusion_matrix(y_traian,train_pred)
sensitivity1 = cm[0,0]/(cm[0,0]+cm[0,1])
print(sensitivity1)
# Out:
# [[268   0]
#  [  5 125]]
# 1.0

# %%
# for testing data

# %%
print(confusion_matrix(y_test,test_pred))
cm2 = confusion_matrix(y_test,test_pred)
sensitivity2 = cm2[0,0]/(cm2[0,0]+cm2[0,1])
print(sensitivity2)
# Out:
# [[87  2]
#  [ 2 80]]
# 0.9775280898876404

# %%
# Specificity

# %%
# for training
specificity1 = cm[1,1]/(cm[1,0]+cm[1,1])
print(specificity1)
# Out:
# 0.9615384615384616

# %%
# for testing
specificity2 = cm2[1,1]/(cm2[1,0]+cm2[1,1])
print(specificity2)
# Out:
# 0.975609756097561

# %% [markdown]
# # Classification_Report

# %%
from sklearn.metrics import classification_report

# %%
# for Train data

# %%
print(classification_report(y_traian,train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       268
#            1       1.00      0.96      0.98       130
#
#     accuracy                           0.99       398
#    macro avg       0.99      0.98      0.99       398
# weighted avg       0.99      0.99      0.99       398

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        89
#            1       0.98      0.98      0.98        82
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# The model is an overfitting model

# %% [markdown]
# # The hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
svc_params = [{"C" :[1,0.5,0.05],"kernel" : ('linear', 'poly', 'rbf', 'sigmoid')}]

clf = GridSearchCV(sup, svc_params, cv = 15)

clf.fit(x_train, y_traian)
# Out:
# GridSearchCV(cv=15, estimator=SVC(probability=True),
#              param_grid=[{'C': [1, 0.5, 0.05],
#                           'kernel': ('linear', 'poly', 'rbf', 'sigmoid')}])

# %%
print(clf.best_params_)
# Out:
# {'C': 0.05, 'kernel': 'linear'}

# %%
sup1 = svm.SVC(C = 0.05 , kernel= 'linear',probability=True)

# %%
sup1.fit(x_train,y_traian)
# Out:
# SVC(C=0.05, kernel='linear', probability=True)

# %%
train_pred1 = sup1.predict(x_train)
test_pred1 = sup1.predict(x_test)

# %%
# Accuracy_Score

# %%
acc_train1 = accuracy_score(y_traian,train_pred1)
acc_test1 = accuracy_score(y_test,test_pred1)
print(acc_train1)
print(acc_test1)
# Out:
# 0.9849246231155779
# 0.9824561403508771

# %%
# Precision_Score

# %%
pre_train1 = precision_score(y_traian,train_pred1)
print(pre_train1)
pre_test1 = precision_score(y_test,test_pred1)
print(pre_test1)
# Out:
# 0.9920634920634921
# 1.0

# %%
# Confusion_matrix
# Train_data 
print(confusion_matrix(y_traian,train_pred1))
# Test_data
print(confusion_matrix(y_test,test_pred1))
# Out:
# [[267   1]
#  [  5 125]]
# [[89  0]
#  [ 3 79]]

# %%
# Senstitiy for train
print(confusion_matrix(y_traian,train_pred1))
cm3 = confusion_matrix(y_traian,train_pred1)
sensitivity_new = cm[0,0]/(cm[0,0]+cm[0,1])
print(sensitivity_new)
# Out:
# [[267   1]
#  [  5 125]]
# 1.0

# %%
print(confusion_matrix(y_test,test_pred1))
cm4 = confusion_matrix(y_test,test_pred1)
sensitivity_test = cm[0,0]/(cm[0,0]+cm[0,1])
print(sensitivity_test)
# Out:
# [[89  0]
#  [ 3 79]]
# 1.0

# %%
# For training data 
print(classification_report(y_traian,train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       268
#            1       0.99      0.96      0.98       130
#
#     accuracy                           0.98       398
#    macro avg       0.99      0.98      0.98       398
# weighted avg       0.99      0.98      0.98       398

# %%
# fr test data

# %%
print(classification_report(y_test,test_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        89
#            1       1.00      0.96      0.98        82
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# # Plotting the ROC and AUC Curve

# %%
from sklearn.metrics import roc_curve

# %%
pred_prob1 = sup1.predict_proba(x_test)
pred_prob2 = sup.predict_proba(x_test)

# %%
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)
print(fpr1, tpr1, thresh1)
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
# Out:
# [0.         0.         0.         0.11235955 0.11235955 0.17977528
#  0.17977528 1.        ] [0.         0.12195122 0.97560976 0.97560976 0.98780488 0.98780488
#  1.         1.        ] [2.00000000e+00 1.00000000e+00 5.47151136e-01 2.39621423e-01
#  1.32939395e-01 8.71775702e-02 7.89868241e-02 4.52519382e-06]

# %%
print(p_fpr, p_tpr,p_thresh)
# Out:
# [0. 1.] [0. 1.] [1 0]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Tuned SVC')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='Before_tuning')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
